# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotimhkd977-lang/Polynomial_Regression/blob/main/Polynomial_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

df = pd.read_csv("Ice_cream selling data.csv")
print(df.head())

X = df[['Temperature (°C)']]
y = df['Ice Cream Sales (units)']

poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

model = LinearRegression()
model.fit(X_poly, y)

print("\n-----Model Intercept & Coefficient-----")
print("Intercept:",model.intercept_)
print("Coefficients:",model.coef_)

y_pred = model.predict(X_poly)

mse = mean_squared_error(y, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y, y_pred)
r2 = r2_score(y, y_pred)

print("\n-----Regression Metrics-----")
print("MSE:", mse)
print("RMSE:", rmse)
print("MAE:", mae)
print("R2 Score:", r2)

print("\n-----Ploting-----")
plt.scatter(X, y, color='blue', label='Actual Data')
sorted_zip = sorted(zip(X.values, y_pred))
X_sorted, y_sorted = zip(*sorted_zip)
plt.plot(X_sorted, y_sorted, color='red', linewidth=3, label='Polynomial Regression')
plt.xlabel("Temperature (°C)")
plt.ylabel("Ice Cream Sales")
plt.title("Polynomial Regression - Ice Cream Sales Prediction")
plt.legend()

plt.show()
# Out:
#    Temperature (°C)  Ice Cream Sales (units)
# 0         -4.662263                41.842986
# 1         -4.316559                34.661120
# 2         -4.213985                39.383001
# 3         -3.949661                37.539845
# 4         -3.578554                32.284531
#
# -----Model Intercept & Coefficient-----
# Intercept: 2.9517741579934444
# Coefficients: [ 0.         -0.82468167  1.82952623]
#
# -----Regression Metrics-----
# MSE: 10.003220594982494
# RMSE: 3.1627868399534127
# MAE: 2.6971548466037953
# R2 Score: 0.9321137090423876
#
# -----Ploting-----
